# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
NRF=[2,3,4,6,9,12,18]

R_mlp=[20.967899322509766,20.365428924560547,20.192108154296875,20.341087341308594,20.336891174316406,21.135723114013672,21.543638229370117]
t_mlp=[8.165359497070313e-05,8.224654197692871e-05,8.679473400115967e-05,9.174370765686035e-05,9.762465953826904e-05,9.717988967895507e-05,0.00011337196826934815]

R_gnn1=[20.1058406829834,21.325204849243164,21.84043312072754,22.175289154052734,22.688337326049805,22.931941986083984,23.549407958984375]
t_gnn1=[0.00011047232151031494,0.00011852836608886719,0.00012801992893218995,0.0001549900770187378,0.00020385801792144776,0.00026523804664611817,0.0003365964889526367]

R_sdraltmin=[]
t_sdraltmin=[]

# %%
plt.plot(NRF,R_mlp,'g-s')
plt.plot(NRF,R_gnn1,'-s',color='orange')
plt.xlabel('$N_{RF}$')
plt.ylabel('Spectral Efficiency ($W-bits/Hz$)')
plt.legend(['mlp','Unrolling'])
plt.grid(True)
plt.show()

# %%
plt.plot(NRF,t_mlp,'g-s')
plt.plot(NRF,t_gnn1,'-s',color='orange')
plt.xlabel('$N_{RF}$')
plt.ylabel('Time for Calculations$(s)$')
plt.legend(['mlp','Unrolling'])
plt.grid(True)
plt.show()
